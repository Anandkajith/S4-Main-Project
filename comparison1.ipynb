# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/ssd-weights/ssdmodeldict (2).pth
# /kaggle/input/faster-rcnn-weights/fasterrcnnogmodel_state_dict.pth
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01028.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01484.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00588.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00286.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00080.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01279.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00440.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02557.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01936.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00733.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00134.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01466.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00709.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00372.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01850.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02017.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02363.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01399.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01713.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02439.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00845.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00275.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00569.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02445.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00074.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00085.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02591.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00562.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02561.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00235.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01289.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00518.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00872.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01324.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00236.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02485.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01556.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02333.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02260.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00553.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00820.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01868.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01947.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01539.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01407.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01313.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02380.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02242.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00083.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01361.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02142.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01900.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00155.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01104.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02520.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00937.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01332.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00949.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01304.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00659.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01745.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00897.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00910.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00523.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00540.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00934.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02259.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00447.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00271.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00707.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02233.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01511.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00819.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01013.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01205.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01860.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00817.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01708.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00221.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02564.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02124.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00560.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00373.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01354.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02282.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01747.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02296.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00194.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00067.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00359.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01583.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00745.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02277.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00725.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01927.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01827.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02231.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00507.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02499.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00770.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00384.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01680.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02164.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00661.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00042.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00366.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02342.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02036.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01929.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00248.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01837.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00590.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02109.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02035.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00558.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02174.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01658.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00771.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00059.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01724.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00598.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02458.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01473.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00530.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00313.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01957.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01329.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01255.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02408.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01846.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01688.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00940.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00439.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02031.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01303.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00982.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00633.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01543.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00699.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01447.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01317.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00813.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01777.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02376.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02412.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01031.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00563.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00460.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01991.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01693.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01349.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01761.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02576.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02378.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01869.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00911.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02533.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01321.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01597.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01629.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01103.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01620.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02012.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01371.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01482.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01081.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02270.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00954.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00785.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01669.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00945.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02212.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01023.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02593.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00118.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01865.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00986.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00402.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01356.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02535.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00796.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01519.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01479.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01365.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00639.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00875.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01430.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00210.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02199.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02061.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00111.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00936.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01733.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01373.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00335.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02519.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02430.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01823.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00030.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00746.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00483.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02316.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01027.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00353.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01689.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02457.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01185.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00567.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02038.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00344.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00539.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00718.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02116.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01646.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02052.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02349.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01710.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01907.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02015.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02295.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00961.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00146.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01157.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00292.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01854.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01082.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02303.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02335.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00300.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01152.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02579.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00629.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01292.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00990.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02180.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01972.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00355.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00304.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01246.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01432.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00551.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01617.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01096.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00852.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01714.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00950.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02054.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00418.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01443.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01116.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00751.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00048.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01922.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02320.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02338.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02292.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01316.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01522.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01129.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00631.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02355.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01825.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00308.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01888.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01165.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00825.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01882.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02086.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01015.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00336.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02011.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02410.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00443.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00979.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01528.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00731.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02568.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02574.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00962.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00054.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01881.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01143.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00815.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01310.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00345.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00814.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00495.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01765.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01226.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02211.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00601.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00116.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02140.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00375.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02315.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01367.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01804.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00452.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00637.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02045.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00763.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00894.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01853.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00278.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01704.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01173.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00320.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02460.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01696.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02532.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02450.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01232.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00754.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01939.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00147.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01357.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01057.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00098.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00031.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00121.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01184.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02205.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01314.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01061.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02347.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00479.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02351.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00123.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02149.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01744.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01305.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00704.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01773.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00219.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01280.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00898.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00173.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00103.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00203.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00096.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01909.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01844.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00014.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02220.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01916.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00144.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02538.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00106.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00285.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01162.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00233.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00531.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01687.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01722.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02444.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00484.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02209.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02330.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01548.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01699.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01541.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02170.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02422.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00012.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01334.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00579.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00379.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01381.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02297.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00635.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02186.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02442.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00010.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00611.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01632.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00554.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02206.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02004.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00093.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02472.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02384.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01717.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00446.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00351.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00453.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00536.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00395.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01757.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02284.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02386.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02482.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01727.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01586.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00076.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00400.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00033.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00665.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01175.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00021.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02387.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01943.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01369.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01272.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01238.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01863.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02309.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00924.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00038.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01588.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00034.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01156.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01934.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02589.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00252.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00784.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01186.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01555.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01968.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01686.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00943.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02401.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01955.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02477.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01200.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02373.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01526.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00748.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01866.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00596.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00206.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00006.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02534.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01988.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01341.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02198.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00890.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02350.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02203.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00786.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02065.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00694.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00605.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01792.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00728.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02115.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00664.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01242.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02537.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01663.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01139.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00967.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02047.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00161.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02135.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00610.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01051.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00457.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01917.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01725.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02169.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01295.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00204.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00473.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02580.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01873.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00764.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02402.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00804.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02293.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00693.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02437.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02592.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00458.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00928.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01956.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00175.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01810.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01605.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01608.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02443.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00469.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00461.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01790.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00541.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01532.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00013.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02151.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02275.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00471.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01715.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00801.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00099.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00068.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00916.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02144.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01445.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01767.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01398.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01472.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01106.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00585.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01794.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01155.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02103.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02364.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00283.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02368.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00969.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01216.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00834.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00424.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00107.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00672.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00853.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01880.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00343.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01071.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00369.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01657.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02447.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00826.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01024.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00678.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01389.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01718.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01508.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01285.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00608.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00374.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02474.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00850.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01690.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02067.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01998.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01832.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02063.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00995.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02509.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00750.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02596.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01122.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01137.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00159.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00891.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01456.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00407.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01525.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01225.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01553.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01118.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01486.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01828.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01590.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01634.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01436.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02132.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01163.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02370.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00660.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00381.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00612.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01683.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00150.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01530.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00877.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00980.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01579.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01606.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00724.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00992.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01191.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02510.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01879.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00195.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00305.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00084.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01977.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01811.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01930.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01266.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00706.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00228.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00211.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00591.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01234.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01762.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02395.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01262.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00498.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02392.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00404.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00423.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00743.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01099.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00599.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02436.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02226.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01437.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00230.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01908.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00636.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00174.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01621.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01231.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02078.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02404.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01993.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02253.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02027.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00185.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00391.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01887.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00255.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02157.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00250.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00303.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01294.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00756.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02497.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02322.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00719.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02489.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00812.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00705.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02193.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00997.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00984.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01339.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02377.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00237.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00017.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01931.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01649.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01217.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00205.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02471.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02096.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02094.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01610.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01912.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02179.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00505.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01871.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00397.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01627.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00472.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01060.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02044.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00976.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00593.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01054.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00421.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01076.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01889.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00528.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00362.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01491.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02022.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00272.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02496.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01857.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01996.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02381.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01918.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02280.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01455.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00966.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00218.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01607.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02427.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00480.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00065.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01513.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01171.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02550.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00874.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02134.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00594.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01753.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02000.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02076.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00730.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01351.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01170.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02500.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02501.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01818.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01282.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02254.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02222.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00759.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02214.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00053.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00777.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01830.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00202.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01838.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01560.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01385.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01179.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00200.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00310.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01858.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02479.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00432.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02010.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00354.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02255.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01394.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00577.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01659.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02467.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01424.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00327.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01401.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01808.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00339.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02547.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01300.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01451.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01403.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01756.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00537.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01755.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02087.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01278.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02529.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00444.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01965.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01224.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01362.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00387.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00394.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01497.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00925.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01126.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01892.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00088.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02219.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00024.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02305.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00467.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00165.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00983.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01797.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01702.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02466.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01151.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01147.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00426.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00124.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00582.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02319.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02084.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00658.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00265.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01964.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01073.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01088.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01360.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02341.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01254.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01410.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01941.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01459.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01582.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00798.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01043.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00702.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00241.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01817.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00139.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00865.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02272.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01444.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00018.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00913.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00653.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02462.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00717.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00025.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01283.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02107.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01975.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01905.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01201.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01384.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02191.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01009.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02339.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00119.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01527.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02125.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00870.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01438.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02195.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00347.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02518.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01706.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01075.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00077.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00776.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01901.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01986.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01067.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02393.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02014.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02440.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00900.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01932.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02024.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01270.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00697.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00740.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00301.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01153.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02161.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01131.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00561.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00805.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02077.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00650.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01529.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01990.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02138.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02356.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02105.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01189.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02016.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01618.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01452.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01574.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00154.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01989.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00692.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02459.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00686.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01478.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01128.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02426.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02463.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02121.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01029.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00971.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01198.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02530.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00620.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02302.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/00057.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01144.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01192.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/02059.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01910.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01132.txt
# /kaggle/input/anti-uav-yolo-1024/valid/labels/01469.txt
# ...
# /kaggle/input/anti-uav-yolo-1024/train/images/01545.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/00513.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/03265.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/03586.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/00969.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/03081.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/01394.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/00276.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/02708.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/04497.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/03218.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/01939.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/01238.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/01359.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/03713.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/00650.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/03152.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/03006.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/03480.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/03019.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/03798.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/04763.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/03893.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/04476.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/02645.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/02953.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/01412.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/00366.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/01380.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/01224.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/02198.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/05143.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/02917.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/03928.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/02430.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/00598.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/04085.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/00726.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/01035.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/00392.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/00005.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/01351.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/05113.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/02498.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/00088.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/00898.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/04917.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/02036.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/02999.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/01440.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/01918.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/04473.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/03131.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/00147.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/03243.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/03187.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/03038.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/00168.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/05028.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/00167.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/02644.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/01287.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/02269.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/00729.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/04841.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/02145.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/02841.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/00850.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/00101.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/02629.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/01326.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/03875.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/02307.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/04996.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/03856.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/02515.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/00876.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/00759.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/04810.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/05175.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/03568.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/05154.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/00188.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/00400.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/02414.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/00814.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/03896.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/04655.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/00622.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/02200.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/02474.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/05120.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/02207.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/02987.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/03952.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/01347.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/02631.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/00620.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/04850.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/01909.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/03212.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/02960.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/01360.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/03641.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/01990.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/03228.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/01416.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/04597.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/04855.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/01495.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/03615.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/00448.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/03190.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/03825.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/02868.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/04227.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/02929.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/03451.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/04779.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/02120.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/00737.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/00644.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/00142.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/04961.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/02234.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/04276.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/04013.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/04201.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/04381.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/03319.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/00175.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/03776.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/00657.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/03093.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/03551.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/01429.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/00750.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/02004.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/03068.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/00716.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/01301.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/01927.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/04534.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/01835.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/04210.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/02626.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/04344.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/02872.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/02465.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/03492.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/04280.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/04244.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/00032.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/02584.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/02523.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/04822.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/03638.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/03308.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/00313.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/01220.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/04817.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/01504.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/02873.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/03550.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/03091.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/04973.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/03588.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/04648.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/00232.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/04300.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/00616.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/02564.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/04038.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/01472.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/02188.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/03262.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/00980.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/04292.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/02500.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/03179.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/03123.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/04316.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/02448.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/01765.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/04411.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/00606.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/01477.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/03344.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/04929.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/02820.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/03109.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/04540.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/04365.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/00845.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/01776.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/01289.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/01770.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/04221.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/04856.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/02213.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/01141.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/01763.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/02922.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/00590.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/04055.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/03620.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/01373.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/04691.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/05024.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/02333.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/01185.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/03721.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/02807.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/02083.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/03225.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/01564.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/02390.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/01025.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/04182.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/02106.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/02491.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/04932.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/00691.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/02834.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/04653.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/04913.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/00659.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/01552.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/01222.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/02998.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/04542.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/04565.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/00180.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/02242.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/01923.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/01810.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/05191.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/00458.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/02668.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/02109.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/00533.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/03688.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/02273.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/04121.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/00304.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/03328.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/02959.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/04505.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/03957.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/00096.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/01057.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/02764.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/04109.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/00112.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/02599.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/04966.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/04707.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/04725.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/01580.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/02831.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/03874.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/03129.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/02765.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/04282.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/00264.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/03277.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/04138.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/03728.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/00040.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/00986.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/03080.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/00018.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/00319.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/01863.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/02784.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/04535.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/02731.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/03617.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/01325.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/00222.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/02956.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/04731.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/03358.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/04801.jpg
# /kaggle/input/anti-uav-yolo-1024/train/images/00117.jpg

# %%
import os
import collections
import pandas as pd
import numpy as np
import functools
import matplotlib.pyplot as plt
import cv2

# %%
from sklearn import preprocessing


import xml.etree.ElementTree as ET

import albumentations as A
from albumentations.pytorch.transforms import ToTensorV2

import torch
import torchvision

from torchvision.models.detection.faster_rcnn import FastRCNNPredictor
from torchvision.models.detection import FasterRCNN
from torchvision.models.detection.rpn import AnchorGenerator

from torch.utils.data import DataLoader, Dataset
from torch.utils.data import SequentialSampler

import glob
import cv2
from PIL import Image

# %%
BASE_PATH = "/kaggle/input/anti-uav-yolo-1024/train"
TXT_PATH = glob.glob("/kaggle/input/anti-uav-yolo-1024/train/labels/*.txt")
IMG_PATH = glob.glob("/kaggle/input/anti-uav-yolo-1024/train/images/*.jpg")

# %%
def convert_format(box, iwidth=1024, iheight=1024):
    x_center, y_center, width, height = box
    
    x_min = int((x_center - width / 2) * iwidth)
    y_min = int((y_center - height / 2) * iheight)
    x_max = int((x_center + width / 2) * iwidth)
    y_max = int((y_center + height / 2) * iheight)
    
    return [x_min, y_min, x_max, y_max]

# %%
import os
from PIL import Image

train_image = []
train_image_path = []
train_image_id = []
train_annotation = []

for img_path in IMG_PATH:
    # Extract image ID
    image_id = os.path.basename(img_path).split('.')[0]
   

    # Construct path for annotation file
    annotation_path = os.path.join("/kaggle/input/anti-uav-yolo-1024/train/labels/", image_id + ".txt")

    # Check if annotation file exists
    if os.path.exists(annotation_path):
        # Check if annotation file is not empty
        if os.path.getsize(annotation_path) > 0:
            Load_image = Image.open(img_path).convert('RGB')
            nmpy_img = Load_image.resize((258, 258))
            train_image.append(np.asarray(nmpy_img))
            train_image_path.append(img_path)
            train_image_id.append(image_id)

            # Read annotation file
            with open(annotation_path) as f:
                lines = f.readlines()
                tmp_lst = lines[0].split(' ')
                startX = float(tmp_lst[1])
                startY = float(tmp_lst[2])
                endX = float(tmp_lst[3])
                endY = float(tmp_lst[4])

                train_annotation.append(convert_format([startX, startY, endX, endY]))
        else:
            print(f"Annotation file is empty for image: {img_path}")
    else:
        print(f"Annotation file not found for image: {img_path}")

print("Images and annotations processed successfully.")
# Out:
# Annotation file is empty for image: /kaggle/input/anti-uav-yolo-1024/train/images/00639.jpg
# Annotation file is empty for image: /kaggle/input/anti-uav-yolo-1024/train/images/00724.jpg
# Annotation file is empty for image: /kaggle/input/anti-uav-yolo-1024/train/images/00579.jpg
# Images and annotations processed successfully.

# %%
df = pd.DataFrame()
df['boxes'] = train_annotation
df['img_path'] = train_image_path
df['labels'] = 'drone'
df['img_id'] = train_image_id

# %%
import numpy as np
from sklearn import preprocessing

enc = preprocessing.LabelEncoder()
df['labels'] = enc.fit_transform(df['labels'])
df['labels'] = np.stack([df['labels'][i]+1 for i in range(len(df['labels']))])

# %%
import numpy as np

# Assuming df['boxes'] contains arrays/lists of coordinates
# Create separate columns for 'xmin', 'ymin', 'xmax', 'ymax'
df[['xmin', 'ymin', 'xmax', 'ymax']] = np.stack(df['boxes'].apply(lambda x: np.array(x)).values)

# Drop the 'boxes' column
df.drop(columns=['boxes'], inplace=True)
df['xmin'] = df['xmin'].astype(float)
df['ymin'] = df['ymin'].astype(float)
df['xmax'] = df['xmax'].astype(float)
df['ymax'] = df['ymax'].astype(float)

# %%
df_removed_damaged1 = df.drop(df[(df.ymin > df.ymax) | (df.xmin > df.xmax)].index)
df_removed_damaged1

mask = (df['ymin'] > 1024) | (df['ymax'] > 1024) | (df['xmin'] > 1024) | (df['xmax'] > 1024)
# Drop rows where the condition is True
df_removed_damaged = df_removed_damaged1.drop(df[mask].index)

# %%
train_ds=df_removed_damaged[:4000]
val_ds=df_removed_damaged[4000:]
train_ds
# Out:
#                                                img_path  labels img_id   xmin  \
# 0     /kaggle/input/anti-uav-yolo-1024/train/images/...       1  04168  566.0
# 1     /kaggle/input/anti-uav-yolo-1024/train/images/...       1  02371  296.0
# 2     /kaggle/input/anti-uav-yolo-1024/train/images/...       1  04377  469.0
# 3     /kaggle/input/anti-uav-yolo-1024/train/images/...       1  00767  576.0
# 4     /kaggle/input/anti-uav-yolo-1024/train/images/...       1  02360  361.0
# ...                                                 ...     ...    ...    ...
# 3995  /kaggle/input/anti-uav-yolo-1024/train/images/...       1  02303  607.0
# 3996  /kaggle/input/anti-uav-yolo-1024/train/images/...       1  02648  477.0
# 3997  /kaggle/input/anti-uav-yolo-1024/train/images/...       1  03674  322.0
# 3998  /kaggle/input/anti-uav-yolo-1024/train/images/...       1  02833  192.0
# 3999  /kaggle/input/anti-uav-yolo-1024/train/images/...       1  00457  333.0
#
#        ymin   xmax   ymax
# 0     703.0  580.0  714.0
# 1     360.0  318.0  383.0
# 2     381.0  481.0  390.0
# 3     594.0  682.0  716.0
# 4     352.0  388.0  381.0
# ...     ...    ...    ...
# 3995  420.0  627.0  436.0
# 3996  747.0  500.0  775.0
# 3997  659.0  340.0  678.0
# 3998  858.0  242.0  900.0
# 3999  500.0  485.0  689.0
#
# [4000 rows x 7 columns]

# %%
class TrainDataset(Dataset):
    def __init__(self, dataframe, image_dir, transforms=None):
        super().__init__()

        self.image_ids = dataframe['img_id'].unique()
        self.df = dataframe
        self.image_dir = image_dir
        self.transforms = transforms
        
    def __getitem__(self, index: int):
        image_id = self.image_ids[index]
        records = self.df[self.df['img_id'] == image_id]
        image = cv2.imread(f'{self.image_dir}/{image_id}.jpg', cv2.IMREAD_COLOR)
        image = cv2.resize(image, (1024, 1024))
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB).astype(np.float32)
        image /= 255.0
        rows, cols = image.shape[:2]

        boxes = records[['xmin', 'ymin', 'xmax', 'ymax']].values

        if len(boxes) == 0:
            target = {
                'boxes': torch.zeros((0, 4), dtype=torch.float32),
                'labels': torch.zeros(0, dtype=torch.int64),
                'image_id': torch.tensor([index]),
                'area': torch.zeros(0, dtype=torch.float32),
                'iscrowd': torch.zeros(0, dtype=torch.int64)
            }
        else:

            area = (boxes[:, 3] - boxes[:, 1]) * (boxes[:, 2] - boxes[:, 0])
            area = torch.as_tensor(area, dtype=torch.float32)

            label = records['labels'].values
            labels = torch.as_tensor(label, dtype=torch.int64)

            # Suppose all instances are not crowd
            iscrowd = torch.zeros((records.shape[0],), dtype=torch.int64)

            target = {
                'boxes': boxes,
                'labels': labels,
                'image_id': torch.tensor([index]),
                'area': area,
                'iscrowd': iscrowd
            }

        if self.transforms:
            sample = {
                'image': image,
                'bboxes': target['boxes'],
                'labels': target['labels']
            }
            sample = self.transforms(**sample)
            image = sample['image']

            # Only stack the boxes if there are non-empty bounding boxes
            if len(sample['bboxes']) > 0:
                target['boxes'] = torch.stack(tuple(map(torch.tensor, zip(*sample['bboxes'])))).permute(1, 0)

        return image, target

    def __len__(self) -> int:
        return self.image_ids.shape[0]

# %%
def get_transform_train():
    return A.Compose([
        #A.Flip(0.5),
        A.ShiftScaleRotate(scale_limit=0.1, rotate_limit=45, p=0.25),
        A.LongestMaxSize(max_size=800, p=1.0),

        # FasterRCNN will normalize.
        A.Normalize(mean=(0, 0, 0), std=(1, 1, 1), max_pixel_value=255.0, p=1.0),
        ToTensorV2(p=1.0)
    ], bbox_params={'format':'pascal_voc', 'label_fields': ['labels']})

def get_transform_valid():
    return A.Compose([
        ToTensorV2(p=1.0)
    ], bbox_params={'format': 'pascal_voc', 'label_fields':['labels']})

# %%
def collate_fn(batch):
    return tuple(zip(*batch))

train_dataset = TrainDataset(train_ds, '/kaggle/input/anti-uav-yolo-1024/train/images', get_transform_train())
valid_dataset = TrainDataset(val_ds, '/kaggle/input/anti-uav-yolo-1024/train/images', get_transform_train())


train_data_loader = DataLoader(
    train_dataset,
    batch_size=16,
    shuffle=True,
    num_workers=4,
    collate_fn=collate_fn
)

valid_data_loader = DataLoader(
    valid_dataset,
    batch_size=8,
    shuffle=False,
    num_workers=4,
    collate_fn=collate_fn
)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda')

# %%
# !pip install pycocotools
# Out:
# Collecting pycocotools
#   Downloading pycocotools-2.0.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.1 kB)
# Requirement already satisfied: matplotlib>=2.1.0 in /opt/conda/lib/python3.10/site-packages (from pycocotools) (3.7.4)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from pycocotools) (1.24.4)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools) (4.47.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools) (2.8.2)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib>=2.1.0->pycocotools) (1.16.0)
# Downloading pycocotools-2.0.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (426 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 426.2/426.2 kB 13.3 MB/s eta 0:00:00
# Installing collected packages: pycocotools
# Successfully installed pycocotools-2.0.7

# %% [markdown]
# # **SSD**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import xml.etree.ElementTree as ET
import cv2
from PIL import Image
import seaborn as sns
import copy
import torch
from torch.utils.data import Dataset,DataLoader,Subset
import torch.optim as optim
import torchvision
from torchvision.models.detection.ssd import SSDHead,det_utils
from torchvision.models.detection import ssd300_vgg16,SSD300_VGG16_Weights
import torchvision.transforms.functional as tf
import albumentations as A
import pycocotools
import torchmetrics
from torchmetrics.detection import MeanAveragePrecision

# %%
model_weights_pth="/kaggle/input/ssd-weights/ssdmodeldict (2).pth"
model=ssd300_vgg16()
num_classes=2
in_channels=det_utils.retrieve_out_channels(model.backbone,(1024,1024))
num_anchors=model.anchor_generator.num_anchors_per_location()
model.head=SSDHead(in_channels=in_channels,num_anchors=num_anchors,
                   num_classes=num_classes)

model.load_state_dict(torch.load(model_weights_pth,map_location=device))
model.to(device)
# Out:
# Downloading: "https://download.pytorch.org/models/vgg16_features-amdegroot-88682ab5.pth" to /root/.cache/torch/hub/checkpoints/vgg16_features-amdegroot-88682ab5.pth
# 100%|██████████| 528M/528M [00:03<00:00, 163MB/s]
# SSD(
#   (backbone): SSDFeatureExtractorVGG(
#     (features): Sequential(
#       (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): ReLU(inplace=True)
#       (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (3): ReLU(inplace=True)
#       (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (6): ReLU(inplace=True)
#       (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (8): ReLU(inplace=True)
#       (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (11): ReLU(inplace=True)
#       (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (13): ReLU(inplace=True)
#       (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (15): ReLU(inplace=True)
#       (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=True)
#       (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (18): ReLU(inplace=True)
#       (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (20): ReLU(inplace=True)
#       (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (22): ReLU(inplace=True)
#     )
#     (extra): ModuleList(
#       (0): Sequential(
#         (0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (2): ReLU(inplace=True)
#         (3): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (4): ReLU(inplace=True)
#         (5): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (6): ReLU(inplace=True)
#         (7): Sequential(
#           (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#           (1): Conv2d(512, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(6, 6), dilation=(6, 6))
#           (2): ReLU(inplace=True)
#           (3): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1))
#           (4): ReLU(inplace=True)
#         )
#       )
#       (1): Sequential(
#         (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#         (1): ReLU(inplace=True)
#         (2): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (3): ReLU(inplace=True)
#       )
#       (2): Sequential(
#         (0): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1))
#         (1): ReLU(inplace=True)
#         (2): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (3): ReLU(inplace=True)
#       )
#       (3-4): 2 x Sequential(
#         (0): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#         (1): ReLU(inplace=True)
#         (2): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1))
#         (3): ReLU(inplace=True)
#       )
#     )
#   )
#   (anchor_generator): DefaultBoxGenerator(aspect_ratios=[[2], [2, 3], [2, 3], [2, 3], [2], [2]], clip=True, scales=[0.07, 0.15, 0.33, 0.51, 0.69, 0.87, 1.05], steps=[8, 16, 32, 64, 100, 300])
#   (head): SSDHead(
#     (classification_head): SSDClassificationHead(
#       (module_list): ModuleList(
#         (0): Conv2d(512, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): Conv2d(1024, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (2): Conv2d(512, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (3): Conv2d(256, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (4-5): 2 x Conv2d(256, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#     )
#     (regression_head): SSDRegressionHead(
#       (module_list): ModuleList(
#         (0): Conv2d(512, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): Conv2d(1024, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (2): Conv2d(512, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (3): Conv2d(256, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (4-5): 2 x Conv2d(256, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#     )
#   )
#   (transform): GeneralizedRCNNTransform(
#       Normalize(mean=[0.48235, 0.45882, 0.40784], std=[0.00392156862745098, 0.00392156862745098, 0.00392156862745098])
#       Resize(min_size=(300,), max_size=300, mode='bilinear')
#   )
# )

# %%
from torchmetrics.detection import MeanAveragePrecision
metric=MeanAveragePrecision(box_format='xyxy',class_metrics=True)
metric.to(device)
# Out:
# MeanAveragePrecision()

# %%
threshold=0.25
iou_threshold=0.75
def preprocess_bbox(prediction):
    
    """Non-max suppression is the final step of these object detection algorithms and is 
       used to select the most appropriate bounding box for the object.
       The NMS takes two things into account
        -The objectiveness score is given by the model
        -The overlap or IOU of the bounding boxes"""
    
    processed_bbox={}
    
    boxes=prediction["boxes"][prediction["scores"]>=threshold]
    scores=prediction["scores"][prediction["scores"]>=threshold]
    labels=prediction["labels"][prediction["scores"]>=threshold]
    nms=torchvision.ops.nms(boxes,scores,iou_threshold=iou_threshold)
            
    processed_bbox["boxes"]=boxes[nms]
    processed_bbox["scores"]=scores[nms]
    processed_bbox["labels"]=labels[nms]
    
    return processed_bbox

# %%
model.eval()
with torch.no_grad():
    for imgs,targets in valid_data_loader:
        imgs=[img.to(device) for img in imgs]
        #targets=[{k:v.to(device) for (k,v) in d.items()} for d in targets]
        targets = [{k: torch.as_tensor(v).detach().to(device) for k, v in t.items()} for t in targets]
        predictions=model(imgs)
        
        results=[]
        for prediction in predictions:
            results.append(preprocess_bbox(prediction))
        
        metric.update(results,targets)
        
results=metric.compute()

# %%
ssd_mean_ap=results["map"].item()
ssd_mean_ap_50=results["map_50"].item()
ssd_mean_ap_75=results["map_75"].item()

print(f"Mean Average Precision[0.5:0.95:0.05] : {ssd_mean_ap:.4f}")
print(f"Mean Average Precision @ 0.5          : {ssd_mean_ap_50:.4f}")
print(f"Mean Average Precision @ 0.75         : {ssd_mean_ap_75:.4f}")
# Out:
# Mean Average Precision[0.5:0.95:0.05] : 0.0144
# Mean Average Precision @ 0.5          : 0.0384
# Mean Average Precision @ 0.75         : 0.0050

# %% [markdown]
# # **Faster rcnn**

# %%
# load  a model; pre-trained on COCO
modelf = torchvision.models.detection.fasterrcnn_resnet50_fpn(pretrained=False, pretrained_backbone=False)

WEIGHTS_FILE = "/kaggle/input/faster-rcnn-weights/fasterrcnnogmodel_state_dict.pth"

num_classes = 2

# get number of input features for the classifier
in_features = modelf.roi_heads.box_predictor.cls_score.in_features

# replace the pre-trained head with a new one
modelf.roi_heads.box_predictor = FastRCNNPredictor(in_features, num_classes)

# Load the traines weights
modelf.load_state_dict(torch.load(WEIGHTS_FILE))

modelf = modelf.to(device)

# %%
modelf.eval()
with torch.no_grad():
    for imgs,targets in valid_data_loader:
        imgs=[img.to(device) for img in imgs]
        #targets=[{k:v.to(device) for (k,v) in d.items()} for d in targets]
        targets = [{k: torch.as_tensor(v).detach().to(device) for k, v in t.items()} for t in targets]
        predictions=model(imgs)
        
        results=[]
        for prediction in predictions:
            results.append(preprocess_bbox(prediction))
        
        metric.update(results,targets)
        
results=metric.compute()

# %%
fast_mean_ap=results["map"].item()
fast_mean_ap_50=results["map_50"].item()
fast_mean_ap_75=results["map_75"].item()

print(f"Mean Average Precision[0.5:0.95:0.05] : {fast_mean_ap*10:.4f}")
print(f"Mean Average Precision @ 0.5          : {fast_mean_ap_50*10:.4f}")
print(f"Mean Average Precision @ 0.75         : {fast_mean_ap_75*10:.4f}")
# Out:
# Mean Average Precision[0.5:0.95:0.05] : 0.1459
# Mean Average Precision @ 0.5          : 0.3842
# Mean Average Precision @ 0.75         : 0.0517

# %%
labels = ['Overall MAP', 'MAP @ IoU 0.5']

#fasterrcnn
fast_data = [fast_mean_ap, fast_mean_ap_50]
#yolo
yolo_data=[0.4404360958920952,0.764410426518142]
# SSD Mean AP data
ssd_data = [ssd_mean_ap, ssd_mean_ap_50]


# Width of a bar
x = range(len(labels))

# Width of a bar
width = 0.25

# Plotting the bars
fig, ax = plt.subplots()
rects1 = ax.bar(x, fast_data, width, label='Faster Mean AP')
rects2 = ax.bar([p + width for p in x], yolo_data, width, label='YOLO')
rects3 = ax.bar([p + 2*width for p in x], ssd_data, width, label='SSD Mean AP')

# Adding labels, title, and legend
ax.set_ylabel('Mean Average Precision (MAP)')
ax.set_title('Comparison of Faster_rcnn Mean AP, YOLO Mean AP, and SSD Mean AP')
ax.set_xticks([p + width for p in x])
ax.set_xticklabels(labels)
ax.legend()

# %%
labels = ['Overall MAP', 'MAP @ IoU 0.5', 'MAP @ IoU 0.75']

# Position of bars on x-axis
x = range(len(labels))

# Width of a bar
width = 0.35

# Plotting Fast Mean AP
plt.figure(figsize=(6, 6))
plt.bar(x, [fast_mean_ap, fast_mean_ap_50, fast_mean_ap_75], width, label='Fast Mean AP')
plt.xlabel('Evaluation Metric')
plt.ylabel('Mean Average Precision (MAP)')
plt.title('Fasterrcnn Mean Average Precision')
plt.xticks(x, labels)
plt.legend()
plt.show()

# Plotting SSD Mean AP
plt.figure(figsize=(6, 6))
plt.bar(x, [ssd_mean_ap, ssd_mean_ap_50, ssd_mean_ap_75], width, label='SSD Mean AP')
plt.xlabel('Evaluation Metric')
plt.ylabel('Mean Average Precision (MAP)')
plt.title('SSD Mean Average Precision')
plt.xticks(x, labels)
plt.legend()
plt.show()

# %%
import json

# Assuming your JSON file is named "data.json"
file_path = "/kaggle/input/ssd-and-faster-rcnn-loss/loss_history (2).json"

# Load the JSON file
with open(file_path, "r") as file:
    data = json.load(file)

# Now, 'data' variable holds the content of your JSON file
print(data)
ssd_train_loss=data['training_loss']
ssd_val_loss=data['validation_loss']
# Out:
# {'training_loss': [0.6598229030609478, 0.597123425107284, 0.5480482851172186, 0.5252666611115627, 0.4952374567189204, 0.47324482768896725, 0.46030934784575894, 0.4465061719082856, 0.43417804261898524, 0.4242676226934411], 'validation_loss': [1.3149351020647682, 1.2073260930749354, 1.1394386631938087, 1.0821473311581917, 1.0243380990649182, 0.9822531968515149, 0.9434715714782516, 0.9185532596992624, 0.891573891345777, 0.8749830597991561]}

# %%
file_path = "/kaggle/input/ssd-and-faster-rcnn-loss/loss_values (1).txt"

# Load the text file
with open(file_path, "r") as file:
    text_data = file.read()
# Now, 'text_data' variable holds the content of your text file
print(text_data)

fast_train_loss= [0.1482902353196245,0.12839949267607678,0.12239842998164037,0.11490442065765374,0.10675544128986053]
fast_val_loss= [0.13660987354262835,0.14213444198008784,0.12176148379633724,0.1135841039851855,0.10653540087843523]
# Out:
# Train Loss
# 0.1482902353196245
# 0.12839949267607678
# 0.12239842998164037
# 0.11490442065765374
# 0.10675544128986053
#
# Validation Loss
# 0.13660987354262835
# 0.14213444198008784
# 0.12176148379633724
# 0.1135841039851855
# 0.10653540087843523

# %%
# Path to the CSV file
csv_file_path = "/kaggle/input/yolo-losses/train loss.csv"
import pandas as pd


# Read the CSV file into a DataFrame
df = pd.read_csv(csv_file_path)

# Print the DataFrame
print(df)
df.columns
# Out:
#    Step  train3 - train/box_loss  train3 - train/box_loss__MIN  \
# 0     1                  1.97110                       1.97110
# 1     2                  2.19919                       2.19919
# 2     3                  2.03805                       2.03805
# 3     4                  1.95093                       1.95093
# 4     5                  1.87086                       1.87086
# 5     6                  1.71617                       1.71617
# 6     7                  1.64615                       1.64615
# 7     8                  1.58824                       1.58824
# 8     9                  1.49391                       1.49391
# 9    10                  1.42364                       1.42364
#
#    train3 - train/box_loss__MAX
# 0                       1.97110
# 1                       2.19919
# 2                       2.03805
# 3                       1.95093
# 4                       1.87086
# 5                       1.71617
# 6                       1.64615
# 7                       1.58824
# 8                       1.49391
# 9                       1.42364
# Index(['Step', 'train3 - train/box_loss', 'train3 - train/box_loss__MIN',
#        'train3 - train/box_loss__MAX'],
#       dtype='object')

# %%
yolo_train_loss = df['train3 - train/box_loss'].tolist()
yolo_val_loss=df2['train3 - val/box_loss'].tolist()
yolo_train_loss
yolo_val_loss=[2.71123,2.91488,
 2.32332,
 2.22223,
 2.01142,
 1.90531,
 1.80032,
 1.66647,
 1.68462,
 1.54292]

# %%
# Path to the CSV file
csv_file_path = "/kaggle/input/yolo-losses/val loss.csv"
import pandas as pd

mean_value = df2['train3 - val/box_loss'].mean()
# Read the CSV file into a DataFrame
df2= pd.read_csv(csv_file_path)
df2['train3 - val/box_loss'].fillna(mean_value, inplace=True)

# Print the DataFrame
print(df2)
df2.columns
# Out:
#    Step  train3 - val/box_loss  train3 - val/box_loss__MIN  \
# 0     1               2.711230                     2.71123
# 1     2               2.914880                     2.91488
# 2     3               2.323320                     2.32332
# 3     4               2.095021                         NaN
# 4     5               2.011420                     2.01142
# 5     6               1.905310                     1.90531
# 6     7               2.095021                         NaN
# 7     8               1.666470                     1.66647
# 8     9               1.684620                     1.68462
# 9    10               1.542920                     1.54292
#
#    train3 - val/box_loss__MAX
# 0                     2.71123
# 1                     2.91488
# 2                     2.32332
# 3                         NaN
# 4                     2.01142
# 5                     1.90531
# 6                         NaN
# 7                     1.66647
# 8                     1.68462
# 9                     1.54292
# /tmp/ipykernel_34/4149996806.py:8: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df2['train3 - val/box_loss'].fillna(mean_value, inplace=True)
# Index(['Step', 'train3 - val/box_loss', 'train3 - val/box_loss__MIN',
#        'train3 - val/box_loss__MAX'],
#       dtype='object')

# %%
import pandas as pd
import matplotlib.pyplot as plt


# Create a figure and axis object
fig, ax = plt.subplots()

# Plot YOLO training loss
ax.plot(yolo_train_loss, label='YOLO Training Loss')

# Plot YOLO validation loss
ax.plot(yolo_val_loss, label='YOLO Validation Loss')

# Add labels and title
ax.set_xlabel('Epochs')
ax.set_ylabel('Loss')
ax.set_title('YOLO Training and Validation Loss')
ax.legend()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
fast_train_loss= [0.1482902353196245,0.12839949267607678,0.12239842998164037,0.11490442065765374,0.10675544128986053]
fast_val_loss= [0.13660987354262835,0.14213444198008784,0.12176148379633724,0.1135841039851855,0.10653540087843523]


# Plotting
plt.plot(fast_train_loss, label='Faster rcnn')
plt.plot(ssd_train_loss, label='SSD')
plt.plot( yolo_train_loss, label='YOLO')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss comparison')
plt.legend()
plt.show()

# %%
plt.plot(fast_val_loss, label='Faster rcnn')
plt.plot(ssd_val_loss, label='SSD')
plt.plot( yolo_val_loss, label='YOLO')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('validation Loss comparison')
plt.legend()
plt.show()
